# %%
import pandas as pd

# %%
df = pd.read_csv('pizza_sales.csv')

# %%
df.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0         1         1     hawaiian_m         1  01-01-2015   11:38:36
# 1         2         2  classic_dlx_m         1  01-01-2015   11:57:40
# 2         3         2  five_cheese_l         1  01-01-2015   11:57:40
# 3         4         2    ital_supr_l         1  01-01-2015   11:57:40
# 4         5         2     mexicana_m         1  01-01-2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza

# %%
df.shape
# Out:
# (48620, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
df.describe(include ='all')
# Out:
#             pizza_id      order_id pizza_name_id      quantity  order_date  \
# count   48620.000000  48620.000000         48620  48620.000000       48620
# unique           NaN           NaN            91           NaN         358
# top              NaN           NaN    big_meat_s           NaN  26-11-2015
# freq             NaN           NaN          1811           NaN         261
# mean    24310.500000  10701.479761           NaN      1.019622         NaN
# std     14035.529381   6180.119770           NaN      0.143077         NaN
# min         1.000000      1.000000           NaN      1.000000         NaN
# 25%     12155.750000   5337.000000           NaN      1.000000         NaN
# 50%     24310.500000  10682.500000           NaN      1.000000         NaN
# 75%     36465.250000  16100.000000           NaN      1.000000         NaN
# max     48620.000000  21350.000000           NaN      4.000000         NaN
#
#        order_time    unit_price   total_price pizza_size pizza_category  \
# count       48620  48620.000000  48620.000000      48620          48620
# unique      16382           NaN           NaN          5              4
# top      12:32:00           NaN           NaN          L        Classic
# freq           26           NaN           NaN      18526          14579
# mean          NaN     16.494132     16.821474        NaN            NaN
# std           NaN      3.621789      4.437398        NaN            NaN
# min           NaN      9.750000      9.750000        NaN            NaN
# 25%           NaN     12.750000     12.750000        NaN            NaN
# 50%           NaN     16.500000     16.500000        NaN            NaN
# 75%           NaN     20.250000     20.500000        NaN            NaN
# max           NaN     35.950000     83.000000        NaN            NaN
#
#                                         pizza_ingredients  \
# count                                               48620
# unique                                                 32
# top     Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# freq                                                 2416
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                       pizza_name
# count                      48620
# unique                        32
# top     The Classic Deluxe Pizza
# freq                        2416
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN

# %%
df.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
df.dtypes
# Out:
# pizza_id               int64
# order_id               int64
# pizza_name_id         object
# quantity               int64
# order_date            object
# order_time            object
# unit_price           float64
# total_price          float64
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
# To change the datatype of order_date to date 
df['order_date'] = pd.to_datetime(df['order_date'],format = '%d-%m-%Y')

# %%
df.dtypes
# Out:
# pizza_id                      int64
# order_id                      int64
# pizza_name_id                object
# quantity                      int64
# order_date           datetime64[ns]
# order_time                   object
# unit_price                  float64
# total_price                 float64
# pizza_size                   object
# pizza_category               object
# pizza_ingredients            object
# pizza_name                   object
# dtype: object

# %%
df.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0         1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1         2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2         3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3         4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4         5         2     mexicana_m         1 2015-01-01   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza

# %%
# !pip install pymysql sqlalchemy
# Out:
# Requirement already satisfied: pymysql in c:\users\its\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: sqlalchemy in c:\users\its\anaconda3\lib\site-packages (2.0.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\its\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\its\anaconda3\lib\site-packages (from sqlalchemy) (4.12.2)

# %%
from sqlalchemy import create_engine

# MySQL connection
username = "root"
password = "Sumit123"
host = "localhost"
port = "3306"
database = "pizza"

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# Write DataFrame to MySQL
table_name = "pizza_sales"   # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

# Read back sample
pd.read_sql("SELECT * FROM pizza_sales LIMIT 5;", engine)
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date      order_time  \
# 0         1         1     hawaiian_m         1 2015-01-01 0 days 11:38:36
# 1         2         2  classic_dlx_m         1 2015-01-01 0 days 11:57:40
# 2         3         2  five_cheese_l         1 2015-01-01 0 days 11:57:40
# 3         4         2    ital_supr_l         1 2015-01-01 0 days 11:57:40
# 4         5         2     mexicana_m         1 2015-01-01 0 days 11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza
